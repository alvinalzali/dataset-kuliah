# %% [markdown]
# <a href="https://colab.research.google.com/github/alvinalzali/Praktikum/blob/main/Tugas_065119134_Muhamad_Alvin_Alzali_5E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#sumber data dari : ics.uci (https://archive.ics.uci.edu/ml/datasets/Yeast)
#Penjelasan singkat dataset Yeast(ragi) :
#1. Sequence Name: Accession number for the SWISS-PROT database
#2. mcg: McGeoch's method for signal sequence recognition.
#3. gvh: von Heijne's method for signal sequence recognition.
#4. alm: Score of the ALOM membrane spanning region prediction program.
#5. mit: Score of discriminant analysis of the amino acid content of the N-terminal region (20 residues long) of mitochondrial and non-mitochondrial proteins.
#6. erl: Presence of "HDEL" substring (thought to act as a signal for retention in the endoplasmic reticulum lumen). Binary attribute.
#7. pox: Peroxisomal targeting signal in the C-terminus.
#8. vac: Score of discriminant analysis of the amino acid content of vacuolar and extracellular proteins.
#9. nuc: Score of discriminant analysis of nuclear localization signals of nuclear and non-nuclear proteins.


attributes = ['Sequence','mcg','gvh','alm','mit','erl','pox','vac','nuc','kind']
df = pd.read_csv("yeast.csv", delimiter = ";", names=attributes)
#menghapus data yang tidak dipakai
df.drop('Sequence', inplace=True, axis=1)
df.drop('pox', inplace=True, axis=1)

# %% [markdown]
# ##Deskripsi Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1484 entries, 0 to 1483
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mcg     1484 non-null   float64
#  1   gvh     1484 non-null   float64
#  2   alm     1484 non-null   float64
#  3   mit     1484 non-null   float64
#  4   erl     1484 non-null   float64
#  5   vac     1484 non-null   float64
#  6   nuc     1484 non-null   float64
#  7   kind    1484 non-null   object
# dtypes: float64(7), object(1)
# memory usage: 92.9+ KB

# %%
df.describe()
# Out:
#                mcg          gvh  ...          vac          nuc
# count  1484.000000  1484.000000  ...  1484.000000  1484.000000
# mean      0.500121     0.499933  ...     0.499885     0.276199
# std       0.137299     0.123924  ...     0.057797     0.106491
# min       0.110000     0.130000  ...     0.000000     0.000000
# 25%       0.410000     0.420000  ...     0.480000     0.220000
# 50%       0.490000     0.490000  ...     0.510000     0.220000
# 75%       0.580000     0.570000  ...     0.530000     0.300000
# max       1.000000     1.000000  ...     0.730000     1.000000
#
# [8 rows x 7 columns]

# %%
df.head()
# Out:
#     mcg   gvh   alm   mit  erl   vac   nuc kind
# 0  0.58  0.61  0.47  0.13  0.5  0.48  0.22  MIT
# 1  0.43  0.67  0.48  0.27  0.5  0.53  0.22  MIT
# 2  0.64  0.62  0.49  0.15  0.5  0.53  0.22  MIT
# 3  0.58  0.44  0.57  0.13  0.5  0.54  0.22  NUC
# 4  0.42  0.44  0.48  0.54  0.5  0.48  0.22  MIT

# %%
df.tail()
# Out:
#        mcg   gvh   alm   mit  erl   vac   nuc kind
# 1479  0.81  0.62  0.43  0.17  0.5  0.53  0.22  ME2
# 1480  0.47  0.43  0.61  0.40  0.5  0.48  0.47  NUC
# 1481  0.67  0.57  0.36  0.19  0.5  0.56  0.22  ME2
# 1482  0.43  0.40  0.60  0.16  0.5  0.53  0.39  NUC
# 1483  0.65  0.54  0.54  0.13  0.5  0.53  0.22  CYT

# %%
df.shape
# Out:
# (1484, 8)

# %% [markdown]
# ##Visualisasi menggunakan Pandas

# %%
df.plot()

# %%
df.plot.hist(bins=10)

# %%
df.groupby('kind').mean().plot(kind="bar")

# %%
df.plot(kind="scatter", x="vac", y="nuc", colorbar=True)

# %% [markdown]
# ##Visualisasi menggunakan Matplotlib

# %%
indeks = df.index
data = df.values

plt.plot(indeks, data[:, :-1])

# %%
data = df.values[:, :-1]
bins = np.linspace(np.min(data.ravel()), np.max(data.ravel(), 0))

plt.hist(data[:, 0], bins, label="vac")
plt.hist(data[:, 1], bins, label="nuc")
plt.show()

# %%
data = df.values

plt.scatter(data[:, 0], data[:, 1])

# %% [markdown]
# ##Visualisasi dengan Seaborn

# %%
sns.countplot(data=df, x="kind")

# %%
sns.histplot(df)

# %%
sns.pairplot(df, hue="kind")
